# %%
#### 上传GEO 数据到GEO数据库
# 1. 访问GEO数据库，注册账号并登录。
# 2. 点击页面右上角的“Submit”按钮，进入数据提交页面。
# 3. 选择适当的数据提交类型（如Series、Sample等），并点击相应的链接。
# 4. 填写相关的元数据，包括实验设计、样本信息、测序平台等。
# 5. 上传数据文件，确保文件格式符合GEO数据库的要求。上传时用ftp协议会上传一堆错误，直接用Aspera
# 6. 提交数据后，等待GEO数据库的审核和处理。
# 7. 审核通过后，数据将被公开发布，并分配一个唯一的GEO访问号（GEO accession number），供其他研究人员访问和引用。
